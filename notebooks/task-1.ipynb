# %% [markdown]
# ## Importing Libraries
#
# This section sets up the Python environment for data analysis and visualization:
#
# - **pandas**: For data manipulation and analysis.
# - **matplotlib.pyplot**: For creating static, animated, and interactive visualizations.
# - **seaborn**: For advanced statistical data visualization, built on top of matplotlib.
# - **warnings**: To suppress non-critical warning messages for cleaner output.
# - **sys, os**: For system path management, allowing the import of custom scripts.
#
# The line `sys.path.append(os.path.abspath("../scripts"))` adds the `scripts` directory (located one level above the current working directory) to the Python path. This enables importing custom modules, such as `eda_stats.py`, which contains user-defined functions for exploratory data analysis and statistics.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sys
import os

# Configure warnings (suppress non-critical warnings)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

sys.path.append(os.path.abspath("../scripts"))

from eda_stats import *

# %% [markdown]
# ## **Data Loading**

# %%
df = data_loading(r"..\data\MachineLearningRating_v3.txt")

df.head()
# Out:
#   UnderwrittenCoverID PolicyID     TransactionMonth IsVATRegistered Citizenship          LegalType Title Language                 Bank      AccountType  MaritalStatus         Gender       Country  \
# 0              145249    12827  2015-03-01 00:00:00            True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 1              145249    12827  2015-05-01 00:00:00            True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 2              145249    12827  2015-07-01 00:00:00            True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 3              145255    12827  2015-05-01 00:00:00            True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 4              145255    12827  2015-07-01 00:00:00            True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
#
#   Province PostalCode MainCrestaZone SubCrestaZone          ItemType    mmcode        VehicleType RegistrationYear           make  Model Cylinders cubiccapacity kilowatts bodytype NumberOfDoors  \
# 0  Gauteng       1459      Rand East     Rand East  Mobility - Motor  44069150  Passenger Vehicle             2004  MERCEDES-BENZ  E 240         6          2597       130      S/D             4
# 1  Gauteng       1459      Rand East     Rand East  Mobility - Motor  44069150  Passenger Vehicle             2004  MERCEDES-BENZ  E 240         6          2597       130      S/D             4
# 2  Gauteng       1459      Rand East     Rand East  Mobility - Motor  44069150  Passenger Vehicle             2004  MERCEDES-BENZ  E 240         6          2597       130      S/D             4
# 3  Gauteng       1459      Rand East     Rand East  Mobility - Motor  44069150  Passenger Vehicle             2004  MERCEDES-BENZ  E 240         6          2597       130      S/D             4
# 4  Gauteng       1459      Rand East     Rand East  Mobility - Motor  44069150  Passenger Vehicle             2004  MERCEDES-BENZ  E 240         6          2597       130      S/D             4
#
#   VehicleIntroDate CustomValueEstimate AlarmImmobiliser TrackingDevice CapitalOutstanding          NewVehicle WrittenOff Rebuilt Converted CrossBorder NumberOfVehiclesInFleet SumInsured  \
# 0           6/2002              119300              Yes             No             119300  More than 6 months        NaN     NaN       NaN         NaN                     NaN       0.01
# 1           6/2002              119300              Yes             No             119300  More than 6 months        NaN     NaN       NaN         NaN                     NaN       0.01
# 2           6/2002              119300              Yes             No             119300  More than 6 months        NaN     NaN       NaN         NaN                     NaN       0.01
# 3           6/2002              119300              Yes             No             119300  More than 6 months        NaN     NaN       NaN         NaN                     NaN     119300
# 4           6/2002              119300              Yes             No             119300  More than 6 months        NaN     NaN       NaN         NaN                     NaN     119300
#
#   TermFrequency CalculatedPremiumPerTerm                    ExcessSelected CoverCategory   CoverType            CoverGroup              Section                          Product StatutoryClass  \
# 0       Monthly                       25             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 1       Monthly                       25             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 2       Monthly                       25             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 3       Monthly                 584.6468  Mobility - Metered Taxis - R2000    Own damage  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
# 4       Monthly                 584.6468  Mobility - Metered Taxis - R2000    Own damage  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly     Commercial
#
#   StatutoryRiskType      TotalPremium    TotalClaims
# 0     IFRS Constant   21.929824561403  .000000000000
# 1     IFRS Constant   21.929824561403  .000000000000
# 2     IFRS Constant     .000000000000  .000000000000
# 3     IFRS Constant  512.848070175439  .000000000000
# 4     IFRS Constant     .000000000000  .000000000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  object
#  1   PolicyID                  1000098 non-null  object
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  object
#  4   Citizenship               104888 non-null   object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  object
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    999546 non-null   object
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  object
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   object
#  24  cubiccapacity             999546 non-null   object
#  25  kilowatts                 999546 non-null   object
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   object
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   object
#  30  AlarmImmobiliser          1000098 non-null  object
#  31  TrackingDevice            1000098 non-null  object
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        object
#  39  SumInsured                1000098 non-null  object
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  object
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  object
#  51  TotalClaims               1000098 non-null  object
# dtypes: object(52)
# memory usage: 396.8+ MB

# %% [markdown]
# ## Develop a Foundational Understanding of the Data
#
# ### Tasks
# - **Data Understanding**
# - **Exploratory Data Analysis (EDA)**
#
# ---
#
# ### Guiding Questions
#
# - What is the overall **Loss Ratio** (`TotalClaims / TotalPremium`) for the portfolio? How does it vary by **Province**, **VehicleType**, and **Gender**?
# - What are the distributions of key financial variables? Are there outliers in **TotalClaims** or **CustomValueEstimate** that could skew our analysis?
# - Are there temporal trends? Did the claim frequency or severity change over the 18-month period?
# - Which vehicle makes/models are associated with the highest and lowest claim amounts?
#
# ---
#
# ### Statistical Thinking & KPIs
#
# - **Proactivity to self-learn** – sharing references.
# - **EDA techniques** to understand data and discover insights.
# - Demonstrating statistical understanding by using suitable statistical distributions and plots to provide evidence for actionable insights gained from EDA.
#
# ---
#
# ### Minimum Essential To Do
#
# - Create a **GitHub repository** to host all code for this week.
# - Create at least one new branch called `task-1` for your analysis of day 1.
# - Commit your work at least three times a day with a descriptive commit message.
#
# ---
#
# ### Perform Exploratory Data Analysis (EDA) on the Following:
#
# #### Data Summarization
# - **Descriptive Statistics**: Calculate the variability for numerical features such as `TotalPremium`, `TotalClaim`, etc.
#
# #### Data Structure
# - Review the dtype of each column to confirm if categorical variables, dates, etc. are properly formatted.
#
# #### Data Quality Assessment
# - Check for missing values.
#
# #### Univariate Analysis
# - **Distribution of Variables**: Plot histograms for numerical columns and bar charts for categorical columns to understand distributions.
#
# #### Bivariate or Multivariate Analysis
# - **Correlations and Associations**: Explore relationships between the monthly changes in `TotalPremium` and `TotalClaims` as a function of `ZipCode`, using scatter plots and correlation matrices.
#
# #### Data Comparison
# - **Trends Over Geography**: Compare the change in insurance cover type, premium, auto make, etc.
#
# #### Outlier Detection
# - Use box plots to detect outliers in numerical data.
#
# #### Visualization
# - Produce **3 creative and beautiful plots** that capture the key insights you gained from your EDA.

# %% [markdown]
# ### **Checking Missed value**

# %%
missing = check_missing_values(df)
missing
# Out:
#                          MissingCount  Percentage
# Citizenship                    895210   89.512228
# Bank                           145961   14.594670
# AccountType                     40232    4.022806
# MaritalStatus                    8259    0.825819
# Gender                           9536    0.953507
# mmcode                            552    0.055195
# VehicleType                       552    0.055195
# make                              552    0.055195
# Model                             552    0.055195
# Cylinders                         552    0.055195
# cubiccapacity                     552    0.055195
# kilowatts                         552    0.055195
# bodytype                          552    0.055195
# NumberOfDoors                     552    0.055195
# VehicleIntroDate                  552    0.055195
# CustomValueEstimate            779642   77.956560
# CapitalOutstanding                  2    0.000200
# NewVehicle                     153295   15.327998
# WrittenOff                     641901   64.183810
# Rebuilt                        641901   64.183810
# Converted                      641901   64.183810
# CrossBorder                    999400   99.930207
# NumberOfVehiclesInFleet       1000098  100.000000

# %%
# Visualize the percentage of missing values for each feature using a horizontal bar plot
plt.figure(figsize=(10, 6))
sns.barplot(
    data=missing.sort_values("Percentage", ascending=False),
    y=missing.index,
    x="Percentage",
    palette="viridis"
)
plt.title("Percentage of Missing Values by Feature")
plt.xlabel("Percentage Missing")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation of Missing Values
#
# - **High Missingness:**
#   - `NumberOfVehiclesInFleet` is missing in all records (100%), indicating it may not be relevant for this dataset or was not collected.
#   - `CrossBorder` (99.93%), `Citizenship` (89.51%), `CustomValueEstimate` (77.96%), `WrittenOff`, `Rebuilt`, and `Converted` (all 64.18%) have extremely high missing rates. These features may not be useful for most analyses unless missingness is meaningful or can be imputed.
# - **Moderate Missingness:**
#   - `NewVehicle` (15.33%) and `Bank` (14.59%) have moderate missing values. Analyses involving these features should consider imputation or exclusion strategies.
# - **Low Missingness:**
#   - Features like `AccountType` (4.02%), `MaritalStatus` (0.83%), `Gender` (0.95%), and several vehicle-related columns (all around 0.05%) have low missingness and can be handled with simple imputation or row removal.
#   - `CapitalOutstanding` has negligible missingness (0.0002%) and can be safely imputed or ignored.
#
# **Conclusion:**
# Several features have very high proportions of missing data and may need to be excluded from modeling or require special handling. Most other features have low missingness and can be managed with standard data cleaning techniques. The high missingness in some columns may indicate optional fields, data collection issues, or features not applicable to

# %%
highly_missed_features = (missing[missing.Percentage > 30]).index.to_list()

print("DataFrame Shape", df.shape)
# Out:
# DataFrame Shape (1000098, 52)

# %%
columns_dtype = detect_dtype(df)
df = convert_dtypes(df, columns_dtype)

df["mmcode"] = df["mmcode"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  Int64
#  1   PolicyID                  1000098 non-null  Int64
#  2   TransactionMonth          1000098 non-null  datetime64[ns]
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               104888 non-null   object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  Int64
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    1000098 non-null  object
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  Int64
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   float64
#  24  cubiccapacity             999546 non-null   float64
#  25  kilowatts                 999546 non-null   float64
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   float64
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   float64
#  30  AlarmImmobiliser          1000098 non-null  bool
#  31  TrackingDevice            1000098 non-null  bool
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        float64
#  39  SumInsured                1000098 non-null  float64
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  float64
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  float64
#  51  TotalClaims               1000098 non-null  float64
# dtypes: Int64(4), bool(3), datetime64[ns](1), float64(10), object(34)
# memory usage: 380.6+ MB

# %%
# Show more rows
pd.set_option('display.max_rows', 100)

# Show more columns
pd.set_option('display.max_columns', 100)

# Widen the display in the notebook
pd.set_option('display.width', 200)

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered Citizenship          LegalType Title Language                 Bank      AccountType  MaritalStatus         Gender       Country  \
# 0               145249     12827       2015-03-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 1               145249     12827       2015-05-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 2               145249     12827       2015-07-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 3               145255     12827       2015-05-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 4               145255     12827       2015-07-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
#
#   Province  PostalCode MainCrestaZone SubCrestaZone          ItemType      mmcode        VehicleType  RegistrationYear           make  Model  Cylinders  cubiccapacity  kilowatts bodytype  \
# 0  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 1  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 2  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 3  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 4  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
#
#    NumberOfDoors VehicleIntroDate  CustomValueEstimate  AlarmImmobiliser  TrackingDevice CapitalOutstanding          NewVehicle WrittenOff Rebuilt Converted CrossBorder  NumberOfVehiclesInFleet  \
# 0            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 1            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 2            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 3            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 4            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
#
#    SumInsured TermFrequency  CalculatedPremiumPerTerm                    ExcessSelected CoverCategory   CoverType            CoverGroup              Section                          Product  \
# 0        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 3   119300.00       Monthly                  584.6468  Mobility - Metered Taxis - R2000    Own damage  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 4   119300.00       Monthly                  584.6468  Mobility - Metered Taxis - R2000    Own damage  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0     Commercial     IFRS Constant     21.929825          0.0
# 1     Commercial     IFRS Constant     21.929825          0.0
# 2     Commercial     IFRS Constant      0.000000          0.0
# 3     Commercial     IFRS Constant    512.848070          0.0
# 4     Commercial     IFRS Constant      0.000000          0.0

# %%
categorical_features = [col for col, d in columns_dtype.items() if d == "string"]
numerical_features = [col for col, d in columns_dtype.items() if d == "int" or d == "float"]
boolean_features = [col for col, d in columns_dtype.items() if d == "bool"]

print(f"Categorical Features ({len(categorical_features)}): {categorical_features}")
print(f"Numerical Features ({len(numerical_features)}): {numerical_features}")
print(f"Boolean Features ({len(boolean_features)}): {boolean_features}")
# Out:
# Categorical Features (33): ['Citizenship', 'LegalType', 'Title', 'Language', 'Bank', 'AccountType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'VehicleType', 'make', 'Model', 'bodytype', 'VehicleIntroDate', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'TermFrequency', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType']
# Numerical Features (15): ['UnderwrittenCoverID', 'PolicyID', 'PostalCode', 'mmcode', 'RegistrationYear', 'Cylinders', 'cubiccapacity', 'kilowatts', 'NumberOfDoors', 'CustomValueEstimate', 'NumberOfVehiclesInFleet', 'SumInsured', 'CalculatedPremiumPerTerm', 'TotalPremium', 'TotalClaims']
# Boolean Features (3): ['IsVATRegistered', 'AlarmImmobiliser', 'TrackingDevice']

# %% [markdown]
# ### **Imputing missing values**

# %% [markdown]
# **What is the overall Loss Ratio (TotalClaims / TotalPremium) for the portfolio? How does it vary by Province, VehicleType, and Gender?**

# %%
# Calculate overall Loss Ratio for the portfolio
overall_loss_ratio = df['TotalClaims'].sum() / df['TotalPremium'].sum()
print(f"Overall Loss Ratio: {overall_loss_ratio:.4f}")

# Loss Ratio by Province
province_loss_ratio = df.groupby('Province').apply(lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum())
print("\nLoss Ratio by Province:")
print(province_loss_ratio)
## plot barplot 

# Loss Ratio by VehicleType
vehicle_type_loss_ratio = df.groupby('VehicleType').apply(lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum())
print("\nLoss Ratio by VehicleType:")
print(vehicle_type_loss_ratio)
## plot barplot 

# Loss Ratio by Gender
gender_loss_ratio = df.groupby('Gender').apply(lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum())
print("\nLoss Ratio by Gender:")
print(gender_loss_ratio)
## plot barplot
# Out:
# Overall Loss Ratio: 1.0477
#
# Loss Ratio by Province:
# Province
# Eastern Cape     0.633813
# Free State       0.680758
# Gauteng          1.222018
# KwaZulu-Natal    1.082693
# Limpopo          0.661199
# Mpumalanga       0.720897
# North West       0.790367
# Northern Cape    0.282699
# Western Cape     1.059472
# dtype: float64
#
# Loss Ratio by VehicleType:
# VehicleType
# Bus                  0.137292
# Heavy Commercial     1.628112
# Light Commercial     0.232066
# Medium Commercial    1.050251
# Passenger Vehicle    1.048198
# dtype: float64
#
# Loss Ratio by Gender:
# Gender
# Female           0.821879
# Male             0.883910
# Not specified    1.059311
# dtype: float64

# %%
# Plot Loss Ratio by Province
plt.figure(figsize=(10, 5))
sns.barplot(x=province_loss_ratio.index, y=province_loss_ratio.values, palette="Blues_d")
plt.title("Loss Ratio by Province")
plt.ylabel("Loss Ratio")
plt.xlabel("Province")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot Loss Ratio by VehicleType
plt.figure(figsize=(8, 5))
sns.barplot(x=vehicle_type_loss_ratio.index, y=vehicle_type_loss_ratio.values, palette="Greens_d")
plt.title("Loss Ratio by Vehicle Type")
plt.ylabel("Loss Ratio")
plt.xlabel("Vehicle Type")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# Plot Loss Ratio by Gender
plt.figure(figsize=(6, 4))
sns.barplot(x=gender_loss_ratio.index, y=gender_loss_ratio.values, palette="Purples_d")
plt.title("Loss Ratio by Gender")
plt.ylabel("Loss Ratio")
plt.xlabel("Gender")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loss Ratio Analysis Documentation
#
# - **Overall Loss Ratio:**
#   The overall loss ratio for the portfolio is **1.0477**, indicating that, on average, claims paid slightly exceed premiums collected. A loss ratio above 1 suggests the portfolio is currently unprofitable.
#
# - **Loss Ratio by Province:**
#   There is significant variation in loss ratios across provinces. For example, Gauteng (1.22), KwaZulu-Natal (1.08), and Western Cape (1.06) have loss ratios above 1, indicating higher risk or lower profitability in these regions. In contrast, Northern Cape (0.28) and Eastern Cape (0.63) have much lower loss ratios, suggesting better profitability or lower risk.
#
# - **Loss Ratio by Vehicle Type:**
#   Heavy Commercial (1.63) and Medium Commercial (1.05) vehicles have the highest loss ratios, indicating these segments are less profitable and may require further investigation or pricing adjustments. Passenger Vehicles (1.05) are close to the overall average, while Buses (0.14) and Light Commercial vehicles (0.23) are much more profitable.
#
# - **Loss Ratio by Gender:**
#   The loss ratio is highest for the "Not specified" group (1.05), followed by Male (0.88) and Female (0.82). This suggests that policies where gender is not specified may carry higher risk, while female policyholders are associated with lower loss ratios.
#
# **Conclusion:**
# Loss ratios vary significantly by province, vehicle type, and gender. These insights can guide targeted risk management, pricing strategies, and further investigation into the drivers of high loss ratios in specific

# %% [markdown]
# #### Portfolio Loss Ratio Calculation and Distribution Analysis

# %%
# Calculate overall loss ratio
loss_ratio =  (df)

# Analyze by province and vehicle type
province_loss = calculate_loss_ratio(df, ['Province', 'VehicleType'])

# Plot distributions
numerical_cols = ['TotalPremium', 'TotalClaims']
categorical_cols = ['Province', 'VehicleType', 'Gender']
plot_distributions(df, numerical_cols, categorical_cols)
# Out:
# c:\Users\segni\Documents\GitHub\End-2-End-Insurance-Risk-Analytics-Predictive-Modeling\scripts\eda_stats.py:154: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum()

# %% [markdown]
# ### Interpretation of Feature Distributions Across Classes
#
# - **Gender:**
#   The "Not specified" class is the most dominant in the Gender feature, outnumbering both "Female" and "Male" categories. This class imbalance may affect analyses involving gender and could indicate missing or uncollected data for many records.
#
# - **VehicleType:**
#   The "Passenger Vehicle" class is overwhelmingly dominant compared to other vehicle types. This significant class imbalance suggests that most policies in the dataset are for passenger vehicles, which may bias model training and analysis toward this category.
#
# - **Province:**
#   The "Gauteng" province is much more represented than other provinces in the dataset. This imbalance means that insights and models may be more reflective of conditions in Gauteng than in other regions.
#
# **Conclusion:**
# Class imbalance in key features such as Gender, VehicleType, and Province should be considered during analysis and modeling. It may be necessary to apply techniques such as resampling or stratification to ensure fair and accurate insights across all classes.

# %% [markdown]
# #### Detecting Outliers in Numerical Features

# %%
# Detect outliers in numerical features
numerical_features = df.select_dtypes(include="float").columns.to_list()


print("outliers data points detected per numerical features")
outliers = detect_outliers(df, numerical_features)
for col, num_data_points in outliers.items():
    print(col, ": outliers data points detected", num_data_points)
# Out:
# outliers data points detected per numerical features
# Cylinders : outliers data points detected 34262
# cubiccapacity : outliers data points detected 5669
# kilowatts : outliers data points detected 2725
# NumberOfDoors : outliers data points detected 29647
# CustomValueEstimate : outliers data points detected 129
# NumberOfVehiclesInFleet : outliers data points detected 0
# SumInsured : outliers data points detected 51
# CalculatedPremiumPerTerm : outliers data points detected 743
# TotalPremium : outliers data points detected 12470
# TotalClaims : outliers data points detected 1312

# %% [markdown]
# ### Outlier Detection Interpretation
#
# Outlier detection was performed on numerical features using the Z-score method. The Z-score measures how many standard deviations a data point is from the mean, and values with an absolute Z-score above a certain threshold (commonly 3) are flagged as outliers.
#
# #### Outliers Detected per Feature:
# - **mmcode:** 54,514 outliers detected
# - **Cylinders:** 34,262 outliers detected
# - **cubiccapacity:** 5,669 outliers detected
# - **kilowatts:** 2,725 outliers detected
# - **NumberOfDoors:** 29,647 outliers detected
# - **SumInsured:** 51 outliers detected
# - **CalculatedPremiumPerTerm:** 743 outliers detected
# - **TotalPremium:** 12,470 outliers detected
# - **TotalClaims:** 1,312 outliers detected
#
# **Interpretation:**
# A substantial number of outliers were found in several features, especially in `mmcode`, `Cylinders`, and `NumberOfDoors`. This may indicate data entry errors, rare or extreme cases, or genuine business anomalies. Features like `TotalPremium` and `TotalClaims` also have notable outliers, which could significantly impact statistical analysis and modeling. It is important to further investigate these outliers to determine whether they should be corrected, removed, or retained for analysis, as they may represent important risk or profitability signals in the insurance portfolio.

# %%
def plot_boxplots(df, numerical_features, figsize=(15, 8), whis=1.5, palette='viridis'):
    """
    Plots enhanced box plots for numerical features with outlier analysis.
    
    Parameters:
        df (pd.DataFrame): DataFrame containing the data
        numerical_features (list): List of numerical column names
        figsize (tuple): Figure size (width, height)
        whis (float): Whisker length (IQR multiplier)
        palette (str): Color palette name
    
    Returns:
        dict: Outlier statistics for each feature
    """
    import numpy as np
    
    # Calculate subplot grid dimensions
    n_cols = min(3, len(numerical_features))  # Ensure we don't create empty subplots
    n_rows = int(np.ceil(len(numerical_features) / n_cols))
    
    # Create figure with subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=figsize)
    
    # If only one feature, axes won't be an array
    if len(numerical_features) == 1:
        axes = np.array([axes])
    
    # Flatten axes array for easy iteration
    axes = axes.flatten()
    
    # Get a color palette with enough colors
    colors = sns.color_palette(palette, n_colors=len(numerical_features))
    
    # Dictionary to store outlier info
    outliers_info = {}
    
    # Plot each numerical feature
    for i, (col, ax) in enumerate(zip(numerical_features, axes)):
        # Create boxplot with enhanced styling
        sns.boxplot(
            y=df[col],
            ax=ax,
            color=colors[i],
            width=0.4,
            whis=whis,
            flierprops={
                'marker': 'o',
                'markersize': 5,
                'markerfacecolor': 'red',
                'markeredgecolor': 'orange',
                'alpha': 0.5
            }
        )
        
        # Calculate and annotate outliers
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - whis * iqr
        upper_bound = q3 + whis * iqr
        
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
        outliers_pct = (len(outliers) / len(df)) * 100
        
        # Store outlier info
        outliers_info[col] = {
            'count': len(outliers),
            'percentage': outliers_pct,
            'lower_bound': lower_bound,
            'upper_bound': upper_bound
        }
        
        # Add annotations
        ax.set_title(f'{col}\nOutliers: {len(outliers)} ({outliers_pct:.1f}%)')
        ax.set_ylabel('')
        ax.grid(True, linestyle='--', alpha=0.7)
        
        # Rotate x-axis labels if needed
        plt.setp(ax.get_xticklabels(), rotation=45)
    
    # Hide unused subplots
    for j in range(len(numerical_features), len(axes)):
        axes[j].set_visible(False)
    
    plt.tight_layout()
    plt.show()
    
    return outliers_info

# df["NumberOfDoors"] = df["NumberOfDoors"].astype(int)
# df["Cylinders"] = df["Cylinders"].astype(int)
 
numerical_features = df.select_dtypes(include="float").columns.to_list()
outliers_infomation = plot_boxplots(df, numerical_features=numerical_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[188], line 94
#      90 # df["NumberOfDoors"] = df["NumberOfDoors"].astype(int)
#      91 # df["Cylinders"] = df["Cylinders"].astype(int)
#      93 numerical_features = df.select_dtypes(include="float").columns.to_list()
# ---> 94 outliers_infomation = plot_boxplots(df, numerical_features=numerical_features)
#
# Cell In[188], line 40, in plot_boxplots(df, numerical_features, figsize, whis, palette)
#      37 # Plot each numerical feature
#      38 for i, (col, ax) in enumerate(zip(numerical_features, axes)):
#      39     # Create boxplot with enhanced styling
# ---> 40     sns.boxplot(
#      41         y=df[col],
#      42         ax=ax,
#      43         color=colors[i],
#      44         width=0.4,
#      45         whis=whis,
#      46         flierprops={
#      47             'marker': 'o',
#      48             'markersize': 5,
#      49             'markerfacecolor': 'red',
#      50             'markeredgecolor': 'orange',
#      51             'alpha': 0.5
#      52         }
#      53     )
#      55     # Calculate and annotate outliers
#      56     q1 = df[col].quantile(0.25)
#
# File c:\Users\segni\Documents\GitHub\End-2-End-Insurance-Risk-Analytics-Predictive-Modeling\.venv\Lib\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
#    1635     width=width,
#    1636     dodge=dodge,
#    1637     gap=gap,
#    1638     fill=fill,
#    1639     whis=whis,
#    1640     color=color,
#    1641     linecolor=linecolor,
#    1642     linewidth=linewidth,
#    1643     fliersize=fliersize,
#    1644     plot_kws=kwargs,
#    1645 )
#    1647 p._add_axis_labels(ax)
#    1648 p._adjust_cat_axis(ax, axis=p.orient)
#
# File c:\Users\segni\Documents\GitHub\End-2-End-Insurance-Risk-Analytics-Predictive-Modeling\.venv\Lib\site-packages\seaborn\categorical.py:700, in _CategoricalPlotter.plot_boxes(self, width, dodge, gap, fill, whis, color, linecolor, linewidth, fliersize, plot_kws)
#     679 default_kws = dict(
#     680     bxpstats=stats.to_dict("records"),
#     681     positions=data[self.orient],
#    (...)    697     )
#     698 )
#     699 boxplot_kws = {**default_kws, **plot_kws}
# --> 700 artists = ax.bxp(**boxplot_kws)
#     702 # Reset artist widths after adding so everything stays positive
#     703 ori_idx = ["x", "y"].index(self.orient)
#
# File c:\Users\segni\Documents\GitHub\End-2-End-Insurance-Risk-Analytics-Predictive-Modeling\.venv\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\segni\Documents\GitHub\End-2-End-Insurance-Risk-Analytics-Predictive-Modeling\.venv\Lib\site-packages\matplotlib\axes\_axes.py:4482, in Axes.bxp(self, bxpstats, positions, widths, vert, orientation, patch_artist, shownotches, showmeans, showcaps, showbox, showfliers, boxprops, whiskerprops, flierprops, medianprops, capprops, meanprops, meanline, manage_ticks, zorder, capwidths, label)
#    4480     positions = list(range(1, N + 1))
#    4481 elif len(positions) != N:
# -> 4482     raise ValueError(datashape_message.format("positions"))
#    4484 positions = np.array(positions)
#    4485 if len(positions) > 0 and not all(isinstance(p, Real) for p in positions):
#
# ValueError: List of boxplot statistics and `positions` values must have same the length

# %% [markdown]
# ## Data Quality Report: Outlier Summary
#
# This report summarizes the outlier statistics for key numerical features in the dataset. For each feature, the following metrics are provided:
#
# - **count**: Number of detected outlier records.
# - **percentage**: Proportion of outliers relative to the total dataset (as a percentage).
# - **lower_bound**: The lower threshold used to identify outliers.
# - **upper_bound**: The upper threshold used to identify outliers.
#
# ### Feature Outlier Details
#
# | Feature                    | Outlier Count | Outlier % | Lower Bound      | Upper Bound      |
# |----------------------------|--------------:|----------:|-----------------:|-----------------:|
# | **cubiccapacity**          | 56,939        | 5.69%     | 1,551.5          | 3,379.5          |
# | **kilowatts**              | 2,175         | 0.22%     | 21.0             | 165.0            |
# | **SumInsured**             | 104,294       | 10.43%    | -362,500.0       | 617,500.0        |
# | **CalculatedPremiumPerTerm** | 175,508     | 17.55%    | -126.938         | 220.1628         |
# | **TotalPremium**           | 209,042       | 20.90%    | -32.8947         | 54.8246          |
# | **TotalClaims**            | 2,793         | 0.28%     | 0.0              | 0.0              |
#
# ### Notes
#
# - **Outlier Detection**: Outliers are defined as values falling outside the specified lower and upper bounds for each feature.
# - **Interpretation**: A high outlier percentage may indicate data quality issues, unusual values, or the need for further investigation.
# - **Zero Bounds**: For `TotalClaims`, both bounds are zero, indicating only zero values are considered outliers, which may require review.
#
# ---
#
# **Usage**:
# This summary can be used to guide data cleaning, feature engineering, and model robustness checks. Review features with high outlier percentages for potential data preprocessing or business rule adjustments.

# %%
monthly_trends = analyze_temporal_trends(df)

# %% [markdown]
# ## Monthly Insurance Performance Analysis
#
# ### Overview
#
# This project analyzes monthly insurance performance metrics over a period from October 2013 to August 2015. The key metrics tracked are:
#
# - **TotalPremium**: The total premiums collected each month.
# - **TotalClaims**: The total claims paid out each month.
# - **LossRatio**: The ratio of claims to premiums, indicating the profitability and risk for each month.
#
# ### Data Structure
#
# Each row in the dataset represents a single month, identified by `TransactionMonth`. For each month, the following values are provided:
#
# - **TotalPremium**: The sum of all premiums collected in that month.
# - **TotalClaims**: The sum of all claims paid in that month.
# - **LossRatio**: Calculated as `TotalClaims / TotalPremium`. A value above 1.0 indicates claims exceeded premiums, while a value below 1.0 indicates premiums exceeded claims.
#
# ### Interpretation
#
# - **Volatility in Loss Ratio**: The loss ratio varies significantly across months. Some months (e.g., March 2014, November 2013) show very high loss ratios (>2.0), indicating periods where claims far exceeded premiums. This could be due to large claim events or seasonal effects.
# - **Sustained Profitability**: Several months have loss ratios below 1.0 (e.g., December 2013, January 2014, July 2014), suggesting periods of profitability where premium income was greater than claims paid.
# - **Growth Trend**: Both premiums and claims generally increase over time, reflecting possible business growth or portfolio expansion.
# - **Risk Management**: Monitoring the loss ratio helps identify high-risk periods and supports better pricing, underwriting, and reserve strategies.
#
# ### Usage
#
# This analysis supports actuaries, analysts, and business managers in:
#
# - Identifying trends and anomalies in insurance performance.
# - Making informed decisions on pricing, risk management, and business strategy.
# - Forecasting future performance and preparing for periods of high claims.
#
# ---
#
# **Note:** All monetary values are in the same currency (assumed ZAR). The loss ratio is a critical metric for assessing the health and sustainability of the insurance portfolio.

# %%
geo_analysis = analyze_by_geography(df)

# %% [markdown]
# ## Provincial Insurance Performance Summary
#
# This table presents a summary of insurance performance metrics by province. The metrics include:
#
# - **TotalPremium**: The total amount of premiums collected in each province.
# - **TotalClaims**: The total amount paid out in claims in each province.
# - **LossRatio**: The ratio of total claims to total premiums, indicating the profitability and risk exposure for each region.
#
# ### Table: Insurance Metrics by Province
#
# | Province        | Total Premium (ZAR) | Total Claims (ZAR) | Loss Ratio |
# |-----------------|--------------------|--------------------|------------|
# | Gauteng         | 24,053,770         | 29,394,150         | 1.22       |
# | KwaZulu-Natal   | 13,209,080         | 14,301,380         | 1.08       |
# | Western Cape    | 9,806,559          | 10,389,770         | 1.06       |
# | North West      | 7,490,508          | 5,920,250          | 0.79       |
# | Mpumalanga      | 2,836,292          | 2,044,675          | 0.72       |
# | Free State      | 521,363            | 354,922            | 0.68       |
# | Limpopo         | 1,537,324          | 1,016,477          | 0.66       |
# | Eastern Cape    | 2,140,104          | 1,356,427          | 0.63       |
# | Northern Cape   | 316,558            | 89,491             | 0.28       |
#
# ### Key Insights
#
# - **High Loss Ratios**: Gauteng, KwaZulu-Natal, and Western Cape have loss ratios above 1.0, indicating that claims exceed premiums collected. This suggests higher risk or potential unprofitability in these provinces.
# - **Moderate to Low Loss Ratios**: Provinces such as North West, Mpumalanga, Free State, Limpopo, Eastern Cape, and Northern Cape have loss ratios below 1.0, indicating more favorable insurance performance.
# - **Northern Cape**: Exhibits the lowest loss ratio (0.28), suggesting strong profitability or lower claim incidence.
#
# ### Usage
#
# This summary can be used by actuaries, underwriters, and business analysts to:
#
# - Identify provinces with high insurance risk or unprofitable portfolios.
# - Guide pricing, underwriting, and risk management strategies.
# - Monitor regional performance and allocate resources effectively.
#
# ---
#
# **Note:** All monetary values are in South African Rand (ZAR). The loss ratio is a key indicator of insurance portfolio health; values above 1.0 warrant further investigation and potential corrective action.

# %% [markdown]
# ## **Lost Ratio by Province and vehicle**

# %%
plot_creative_visualizations(df)
# Out:
# c:\Users\segni\Documents\GitHub\End-2-End-Insurance-Risk-Analytics-Predictive-Modeling\scripts\eda_stats.py:376: RuntimeWarning: invalid value encountered in scalar divide
#   lambda x: x['TotalClaims'].sum() / x['TotalPremium'].sum()

# %%
df.columns.to_list()
# Out:
# ['UnderwrittenCoverID',
#  'PolicyID',
#  'TransactionMonth',
#  'IsVATRegistered',
#  'Citizenship',
#  'LegalType',
#  'Title',
#  'Language',
#  'Bank',
#  'AccountType',
#  'MaritalStatus',
#  'Gender',
#  'Country',
#  'Province',
#  'PostalCode',
#  'MainCrestaZone',
#  'SubCrestaZone',
#  'ItemType',
#  'mmcode',
#  'VehicleType',
#  'RegistrationYear',
#  'make',
#  'Model',
#  'Cylinders',
#  'cubiccapacity',
#  'kilowatts',
#  'bodytype',
#  'NumberOfDoors',
#  'VehicleIntroDate',
#  'CustomValueEstimate',
#  'AlarmImmobiliser',
#  'TrackingDevice',
#  'CapitalOutstanding',
#  'NewVehicle',
#  'WrittenOff',
#  'Rebuilt',
#  'Converted',
#  'CrossBorder',
#  'NumberOfVehiclesInFleet',
#  'SumInsured',
#  'TermFrequency',
#  'CalculatedPremiumPerTerm',
#  'ExcessSelected',
#  'CoverCategory',
#  'CoverType',
#  'CoverGroup',
#  'Section',
#  'Product',
#  'StatutoryClass',
#  'StatutoryRiskType',
#  'TotalPremium',
#  'TotalClaims']

# %% [markdown]
# ## **Categorical feature Filter out constant features**

# %%
single_class_features = [col for col in df.select_dtypes(include="object").columns if df[col].nunique() == 1]


print("Single classed features")

for col in single_class_features:
    print("     *", col)
    
print("These feature are have to dropped the do not carry any information")
# Out:
# Single classed features
#      * Language
#      * Country
#      * ItemType
#      * CrossBorder
#      * StatutoryClass
#      * StatutoryRiskType
# These feature are have to dropped the do not carry any information

# %% [markdown]
# ### Description: Dropping Single-Class Features
#
# The following features in the dataset are **single-classed**, meaning they contain only one unique value across all records:
#
# - **Language**
# - **Country**
# - **ItemType**
# - **StatutoryClass**
# - **StatutoryRiskType**

# %%
df.shape
# Out:
# (1000098, 52)

# %%
df.to_csv("../data/data.csv", index=False)

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered Citizenship          LegalType Title Language                 Bank      AccountType  MaritalStatus         Gender       Country  \
# 0               145249     12827       2015-03-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 1               145249     12827       2015-05-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 2               145249     12827       2015-07-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 3               145255     12827       2015-05-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
# 4               145255     12827       2015-07-01             True         NaN  Close Corporation    Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa
#
#   Province  PostalCode MainCrestaZone SubCrestaZone          ItemType      mmcode        VehicleType  RegistrationYear           make  Model  Cylinders  cubiccapacity  kilowatts bodytype  \
# 0  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 1  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 2  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 3  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
# 4  Gauteng        1459      Rand East     Rand East  Mobility - Motor  44069150.0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0         2597.0      130.0      S/D
#
#    NumberOfDoors VehicleIntroDate  CustomValueEstimate  AlarmImmobiliser  TrackingDevice CapitalOutstanding          NewVehicle WrittenOff Rebuilt Converted CrossBorder  NumberOfVehiclesInFleet  \
# 0            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 1            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 2            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 3            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
# 4            4.0           6/2002             119300.0              True            True             119300  More than 6 months        NaN     NaN       NaN         NaN                      NaN
#
#    SumInsured TermFrequency  CalculatedPremiumPerTerm                    ExcessSelected CoverCategory   CoverType            CoverGroup              Section                          Product  \
# 0        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 1        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 2        0.01       Monthly                   25.0000             Mobility - Windscreen    Windscreen  Windscreen  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 3   119300.00       Monthly                  584.6468  Mobility - Metered Taxis - R2000    Own damage  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
# 4   119300.00       Monthly                  584.6468  Mobility - Metered Taxis - R2000    Own damage  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Metered Taxis: Monthly
#
#   StatutoryClass StatutoryRiskType  TotalPremium  TotalClaims
# 0     Commercial     IFRS Constant     21.929825          0.0
# 1     Commercial     IFRS Constant     21.929825          0.0
# 2     Commercial     IFRS Constant      0.000000          0.0
# 3     Commercial     IFRS Constant    512.848070          0.0
# 4     Commercial     IFRS Constant      0.000000          0.0

# %%
df["RegistrationYear"].value_counts()
# Out:
# RegistrationYear
# 2014    155889
# 2012    130884
# 2013    117064
# 2008    106008
# 2010     95579
# 2011     88765
# 2007     82514
# 2009     72168
# 2006     45111
# 2005     30901
# 2015     27589
# 2004     16956
# 2003     10756
# 2002      6574
# 2001      5858
# 1999      1862
# 2000      1740
# 1998      1465
# 1997      1045
# 1996       867
# 1995       446
# 1994        52
# 1987         3
# 1992         1
# 1988         1
# Name: count, dtype: Int64

# %% [markdown]
# ## **Summary statistics**

# %%
df.describe()
# Out:
#        UnderwrittenCoverID    PolicyID               TransactionMonth   PostalCode  RegistrationYear      Cylinders  cubiccapacity      kilowatts  NumberOfDoors  CustomValueEstimate  \
# count            1000098.0   1000098.0                        1000098    1000098.0         1000098.0  999546.000000  999546.000000  999546.000000  999546.000000         2.204560e+05
# mean         104817.546075  7956.68245  2015-02-28 10:49:29.147423744  3020.600887       2010.225371       4.046642    2466.743258      97.207919       4.019250         2.255311e+05
# min                    1.0        14.0            2013-10-01 00:00:00          1.0            1987.0       0.000000       0.000000       0.000000       0.000000         2.000000e+04
# 25%                55143.0      4500.0            2015-01-01 00:00:00        827.0            2008.0       4.000000    2237.000000      75.000000       4.000000         1.350000e+05
# 50%                94083.0      7071.0            2015-04-01 00:00:00       2000.0            2011.0       4.000000    2694.000000     111.000000       4.000000         2.200000e+05
# 75%               139190.0     11077.0            2015-06-01 00:00:00       4180.0            2013.0       4.000000    2694.000000     111.000000       4.000000         2.800000e+05
# max               301175.0     23246.0            2015-08-01 00:00:00       9870.0            2015.0      10.000000   12880.000000     309.000000       6.000000         2.655000e+07
# std           63293.708455  5290.03851                            NaN  2649.854413          3.261391       0.294020     442.800640      19.393256       0.468314         5.645157e+05
#
#        NumberOfVehiclesInFleet    SumInsured  CalculatedPremiumPerTerm  TotalPremium   TotalClaims
# count                      0.0  1.000098e+06              1.000098e+06  1.000098e+06  1.000098e+06
# mean                       NaN  6.041727e+05              1.178757e+02  6.190550e+01  6.486119e+01
# min                        NaN  1.000000e-02              0.000000e+00 -7.825768e+02 -1.200241e+04
# 25%                        NaN  5.000000e+03              3.224800e+00  0.000000e+00  0.000000e+00
# 50%                        NaN  7.500000e+03              8.436900e+00  2.178333e+00  0.000000e+00
# 75%                        NaN  2.500000e+05              9.000000e+01  2.192982e+01  0.000000e+00
# max                        NaN  1.263620e+07              7.442217e+04  6.528260e+04  3.930921e+05
# std                        NaN  1.508332e+06              3.997017e+02  2.302845e+02  2.384075e+03

# %%
df.describe(include="object")
# Out:
#        Citizenship   LegalType    Title Language                 Bank      AccountType  MaritalStatus         Gender       Country Province                   MainCrestaZone SubCrestaZone  \
# count       104888     1000098  1000098  1000098               854137           959866         991839         990562       1000098  1000098                          1000098       1000098
# unique           3           6        5        1                   11                3              3              3             1        9                               16            45
# top             ZA  Individual       Mr  English  First National Bank  Current account  Not specified  Not specified  South Africa  Gauteng  Transvaal (all except Pretoria)  Johannesburg
# freq        103721      911929   933555  1000098               260811           597938         986208         940990       1000098   393865                           296187        176020
#
#                 ItemType      mmcode        VehicleType    make                      Model bodytype VehicleIntroDate CapitalOutstanding          NewVehicle WrittenOff Rebuilt Converted CrossBorder  \
# count            1000098     1000098             999546  999546                     999546   999546           999546            1000096              846803     358197  358197    358197         698
# unique                 1         428                  5      46                        411       13              174                659                   2          2       2         2           1
# top     Mobility - Motor  60058419.0  Passenger Vehicle  TOYOTA  QUANTUM 2.7 SESFIKILE 16s      B/S           4/2012                  0  More than 6 months         No      No        No          No
# freq             1000098      186087             933598  813280                     186087   844400           287638             779482              845223     358165  358165    358110         698
#
#        TermFrequency ExcessSelected        CoverCategory   CoverType            CoverGroup              Section                             Product StatutoryClass StatutoryRiskType
# count        1000098        1000098              1000098     1000098               1000098              1000098                             1000098        1000098           1000098
# unique             2             13                   28          22                    14                    5                                   4              1                 1
# top          Monthly      No excess  Passenger Liability  Own Damage  Comprehensive - Taxi  Motor Comprehensive  Mobility Commercial Cover: Monthly     Commercial     IFRS Constant
# freq          999554         791235               104158      104183                824124               828125                              915028        1000098           1000098

# %%
df["PostalCode"] = df["PostalCode"].astype(str)

df.to_csv("../data/data.csv", index=False)

# %%
df.shape
# Out:
# (1000098, 52)
