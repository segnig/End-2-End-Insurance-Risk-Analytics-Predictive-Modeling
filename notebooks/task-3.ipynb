# %% [markdown]
# # **A/B Hypothesis Testing Analysis**

# %% [markdown]
# Risk Metrics:
# * Claim Frequency: Proportion of policies with at least one claim
# * Claim Severity: Average claim amount when a claim occurs
#
# Profit Metric:
# * Margin: TotalPremium - TotalClaims

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sys
import os

# Configure warnings (suppress non-critical warnings)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

sys.path.append(os.path.abspath("../scripts"))

from hypothesis_testing import *

# %%
risk_analyzer = InsuranceRiskAnalyzer()

risk_analyzer.df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
# 3               145255     12827       2015-05-01             True
# 4               145255     12827       2015-07-01             True
#
#            LegalType Title                 Bank      AccountType  \
# 0  Close Corporation    Mr  First National Bank  Current account
# 1  Close Corporation    Mr  First National Bank  Current account
# 2  Close Corporation    Mr  First National Bank  Current account
# 3  Close Corporation    Mr  First National Bank  Current account
# 4  Close Corporation    Mr  First National Bank  Current account
#
#    MaritalStatus         Gender  ...   CoverType            CoverGroup  \
# 0  Not specified  Not Specified  ...  Windscreen  Comprehensive - Taxi
# ...

# %%
risk_analyzer.get_sample()
# Out:
#         UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 2143                 138375     12071       2015-04-01             True
# 2144                 138375     12071       2015-06-01             True
# 2289                 138375     12071       2015-08-01             True
# 2290                 138374     12071       2015-02-01             True
# 2291                 138369     12071       2015-03-01             True
# ...                     ...       ...              ...              ...
# 996517                 1672       195       2014-04-01             True
# 996518                 1672       195       2014-06-01             True
# 996519                 1672       195       2014-08-01             True
# 996520                 1672       195       2014-10-01             True
# 996521                 1672       195       2014-12-01             True
#
#          LegalType Title           Bank      AccountType  MaritalStatus  \
# ...
